# %%
#import all the libraries
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import os
import glob
import skimage.io as io
from PIL import Image
from skimage.viewer import ImageViewer
import matplotlib.pyplot as plt
from model import *
# Out:
# Using TensorFlow backend.
# C:\Users\Fashiar\Anaconda3\envs\mycoco\lib\site-packages\skimage\viewer\utils\core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "

# %%
def trainGenerator(image_path,mask_path,flag_multi_class = False,num_class = 2,image_prefix = "image",mask_prefix = "mask",image_as_gray = True,mask_as_gray = True):
    image_name_arr = glob.glob(os.path.join(image_path,"*.png"))
    mask_name_arr = glob.glob(os.path.join(mask_path, "*.png"))
    image_arr = []
    mask_arr = []
    for index,item in enumerate(image_name_arr):
        img = io.imread(item,as_gray = image_as_gray)
        img = np.reshape(img,img.shape + (1,)) if image_as_gray else img
        img = img / 255
        image_arr.append(img)

    for index, item in enumerate(mask_name_arr):
        mask = io.imread(item, as_gray = image_as_gray)
        mask = np.reshape(mask,mask.shape + (1,)) if mask_as_gray else mask
        mask = mask/255
        mask[mask>0.5] = 1
        mask[mask<=0.5] = 0
        mask_arr.append(mask)

    image_arr = np.array(image_arr)
    mask_arr = np.array(mask_arr)
    return image_arr,mask_arr

# %%
def testGenerator(test_path, image_num):
    for i in range(image_num):
        idx = str(i+1).zfill(5) + ".png"
        img = io.imread(os.path.join(test_path, idx), as_gray=True)
        img = img / 255
        img = np.reshape(img, img.shape + (1,))
        img = np.reshape(img,(1,)+img.shape)
        yield img

# %%
def getItem(img_path, item):
    idx = str(item+1).zfill(5) + ".png"
    img = io.imread(os.path.join(img_path, idx), as_gray=True)
    img = img/255.0
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,)+img.shape)
    return img

# %%
def saveResult(save_path, files):
    for i, item in enumerate(files):
        img = item[:,:,0]
        idx = str(i+1).zfill(5) + ".png"
        io.imsave(os.path.join(save_path, idx), img)

# %%
def viewImage(array1, array2, i):
    img = np.reshape(array1[i], (256, 256))
    mask = np.reshape(array2[i], (256, 256))
    f, axarr = plt.subplots(1,2)
    axarr[0].imshow(img, cmap=plt.cm.gray)
    axarr[1].imshow(mask, cmap=plt.cm.gray)
    plt.show()

# %%
# Load the train data and their corresponding labels
# Visualize a sample image
imgs_train,imgs_mask_train= trainGenerator("train/images/","train/masks/")
print(imgs_train.shape)   
print(imgs_mask_train.shape)
index = np.random.randint(1, 100)
viewImage(imgs_train, imgs_mask_train, index)
# Out:
# (500, 256, 256, 1)
# (500, 256, 256, 1)

# %%
# laod model and show the model summary
model = unet()
model_checkpoint = ModelCheckpoint('fiber_segmentation.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 147584      conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 512)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 1024) 9438208     conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 1024) 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1024) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1024) 0           dropout_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 512)  0           conv2d_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 256 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 256 0           conv2d_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 128 147584      conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 128 0           conv2d_2[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 1)  3           conv2d_23[0][0]
# ==================================================================================================
# Total params: 31,031,685
# Trainable params: 31,031,685
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\Users\Fashiar\Research\DL\Unet\using_keras\SEM\github_upload\model.py:54: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)

# %%
# train the model
hm_epochs = 20
batch_size = 10
model.fit(imgs_train, imgs_mask_train, batch_size=batch_size, epochs=hm_epochs, verbose=1,
          validation_split=0.2, shuffle=True, callbacks=[model_checkpoint])
# Out:
# Train on 400 samples, validate on 100 samples
# Epoch 1/20
# 400/400 [==============================] - 24s 61ms/step - loss: 0.3523 - acc: 0.8996 - val_loss: 0.3525 - val_acc: 0.9214
#
# Epoch 00001: loss improved from inf to 0.35232, saving model to fiber_segmentation.hdf5
# Epoch 2/20
# 400/400 [==============================] - 16s 40ms/step - loss: 0.1362 - acc: 0.9215 - val_loss: 0.2433 - val_acc: 0.9214
#
# Epoch 00002: loss improved from 0.35232 to 0.13618, saving model to fiber_segmentation.hdf5
# Epoch 3/20
# 400/400 [==============================] - 16s 40ms/step - loss: 0.1084 - acc: 0.9215 - val_loss: 0.2228 - val_acc: 0.9214
#
# Epoch 00003: loss improved from 0.13618 to 0.10843, saving model to fiber_segmentation.hdf5
# Epoch 4/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0986 - acc: 0.9215 - val_loss: 0.2097 - val_acc: 0.9214
#
# Epoch 00004: loss improved from 0.10843 to 0.09863, saving model to fiber_segmentation.hdf5
# Epoch 5/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0936 - acc: 0.9666 - val_loss: 0.3095 - val_acc: 0.9015
#
# Epoch 00005: loss improved from 0.09863 to 0.09357, saving model to fiber_segmentation.hdf5
# Epoch 6/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0895 - acc: 0.9816 - val_loss: 0.2225 - val_acc: 0.9471
#
# Epoch 00006: loss improved from 0.09357 to 0.08946, saving model to fiber_segmentation.hdf5
# Epoch 7/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0872 - acc: 0.9831 - val_loss: 0.1673 - val_acc: 0.9674
#
# Epoch 00007: loss improved from 0.08946 to 0.08721, saving model to fiber_segmentation.hdf5
# Epoch 8/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0851 - acc: 0.9838 - val_loss: 0.1618 - val_acc: 0.9580
#
# Epoch 00008: loss improved from 0.08721 to 0.08513, saving model to fiber_segmentation.hdf5
# Epoch 9/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0829 - acc: 0.9850 - val_loss: 0.1448 - val_acc: 0.9702
#
# Epoch 00009: loss improved from 0.08513 to 0.08287, saving model to fiber_segmentation.hdf5
# Epoch 10/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0801 - acc: 0.9863 - val_loss: 0.1533 - val_acc: 0.9630
#
# Epoch 00010: loss improved from 0.08287 to 0.08009, saving model to fiber_segmentation.hdf5
# Epoch 11/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0787 - acc: 0.9869 - val_loss: 0.1690 - val_acc: 0.9542
#
# Epoch 00011: loss improved from 0.08009 to 0.07867, saving model to fiber_segmentation.hdf5
# Epoch 12/20
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0780 - acc: 0.9873 - val_loss: 0.1679 - val_acc: 0.9556
#
# Epoch 00012: loss improved from 0.07867 to 0.07804, saving model to fiber_segmentation.hdf5
# Epoch 13/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0776 - acc: 0.9876 - val_loss: 0.1127 - val_acc: 0.9779
#
# Epoch 00013: loss improved from 0.07804 to 0.07763, saving model to fiber_segmentation.hdf5
# Epoch 14/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0761 - acc: 0.9881 - val_loss: 0.1691 - val_acc: 0.9517
#
# Epoch 00014: loss improved from 0.07763 to 0.07614, saving model to fiber_segmentation.hdf5
# Epoch 15/20
# 400/400 [==============================] - 17s 41ms/step - loss: 0.0767 - acc: 0.9881 - val_loss: 0.0971 - val_acc: 0.9844
#
# Epoch 00015: loss did not improve from 0.07614
# Epoch 16/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0743 - acc: 0.9888 - val_loss: 0.1278 - val_acc: 0.9716
#
# Epoch 00016: loss improved from 0.07614 to 0.07432, saving model to fiber_segmentation.hdf5
# Epoch 17/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0729 - acc: 0.9894 - val_loss: 0.1467 - val_acc: 0.9628
#
# Epoch 00017: loss improved from 0.07432 to 0.07285, saving model to fiber_segmentation.hdf5
# Epoch 18/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0728 - acc: 0.9894 - val_loss: 0.1163 - val_acc: 0.9759
#
# Epoch 00018: loss improved from 0.07285 to 0.07279, saving model to fiber_segmentation.hdf5
# Epoch 19/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0718 - acc: 0.9898 - val_loss: 0.1503 - val_acc: 0.9589
#
# Epoch 00019: loss improved from 0.07279 to 0.07180, saving model to fiber_segmentation.hdf5
# Epoch 20/20
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0711 - acc: 0.9899 - val_loss: 0.1696 - val_acc: 0.9456
#
# Epoch 00020: loss improved from 0.07180 to 0.07110, saving model to fiber_segmentation.hdf5

# %%
# testing with new images
# the test image folder contains 30 images
test_path = 'test/images/'
test_image_arr = glob.glob(os.path.join(test_path, "*.png"))
num_of_test_images = len(test_image_arr)

testGene = testGenerator(test_path, num_of_test_images)

results = model.predict_generator(testGene, num_of_test_images, verbose=1)

# save the segmentation result in the "outputs" folder
saveResult("outputs/", results)
# Out:
# 30/30 [==============================] - 1s 18ms/step
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# load the trained model
print("model loading...")
trained_model = load_model('fiber_segmentation.hdf5')
print("model loaded succesfully!!!")
# Out:
# model loading...
# model loaded succesfully!!!

# %%
# showing the demo with any random number of images from the test folder
hm_demo = 5
idxs = np.random.randint(1, 30, hm_demo)
for item in idxs:
    testimg = getItem(test_path, item)
    result = trained_model.predict(testimg)
    f, axarr = plt.subplots(1, 2)
    axarr[0].imshow(np.reshape(testimg, (256, 256)), cmap='gray')
    axarr[1].imshow(np.reshape(result, (256,256)), cmap='gray')
